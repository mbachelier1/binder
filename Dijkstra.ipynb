# %% [markdown]
# <div style="padding:5px; border-radius:10px;background-color:lightsalmon;">
#
# <h1 style="text-align:center;color:black;"> Algorithe de Dijkstra (prononcer : "Dekstra")</h1>
# <h3 style="text-align:center;"> Terminale NSI</h3>
#
# <h4 style="text-align:center;"> MB  </h4>
#
#
# </div>

# %% [markdown]
# *Le but de l’activité est de découvrir et mettre en oeuvre l'algorithme Dijkstra, permettant d'optimiser un trajet en minimisant distance, temps de parcours ou coût.*

# %% [markdown]
# <h2 style="color: orange; font-style: 16px italic verdana;"> Compréhension de l'algorithme</h2>
#
#
# ![MetroLondres](https://raw.githubusercontent.com/PythonLycee/PyLyc/master/SNT/img/Dijkstra1.png)
#
#
#
# <video controls src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/SNT/video/Dijkstra.mp4" width="960" height="540" />

# %% [markdown]
# <h2 style="color: orange; font-style: 16px italic verdana;"> Application </h2>

# %%
G1 = { 'B':{'G':1,'O':3} , 
       'E':{'W':2,'P':4} , 
       'G':{'B':1,'O':2,'P':2,'W':3} , 
       'H':{'P':4,'O':1,'K':3} , 
       'K':{'O':5,'H':3} , 
       'O':{'B':3,'G':2,'P':1,'H':1,'K':5} , 
       'P':{'E':4,'G':2,'O':1,'H':4} , 
       'W':{'G':3,'E':2} 
     }

# %% [markdown]
# <h2 style="color: orange; font-style: 16px italic verdana;"> Pseudo code</h2>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     On donne un pseudo-code de cet algorithme (certaines précisions sont volontairement absentes pour vous obliger à réfléhir).
#
# ![image.png](attachment:image.png)
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
#     Implémenter en python la fonction ci-dessous qui prend en argument un graphe pondéré, un sommet de départ un sommet d'arrivée et qui renvoie le chemin dont le temps de parcourt sera le plus petit sous la forme d'une liste donnant dans l'ordre les étapes du parcours.</div>

# %%
def dijkstra(Graphe,depart,arrivee):
    '''Graphe est un graphe pondéré implémenté dans un dictionnaire comme G1
    depart et arrivee sont les nom des noeuds de départ et d'arrivée de l'itinéraire'''
    pass

# %%
assert dijkstra(G1,'W','K')==(['W', 'G', 'O', 'H', 'K'], 9)
assert dijkstra(G1,'E','O')==(['E', 'P', 'O'], 5)
assert dijkstra(G1,'H','H')== (['H'], 0)

# %% [markdown]
# <h2 style="color: orange; font-style: 16px italic verdana;"> Utilisation de l'algorithme</h2>

# %% [markdown]
# Il souhaiterait cependant un peu d'aide pour se rendre de Louhansk à Lviv au plus vite.

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
# Remplir le tableau à la main (comme dans la vidéo) pour l'aider car à Louhansk en ce moment on ne capte pas bien.</div>

# %% [markdown]
# |Kherson|Kharkiv|Soumi|Simferopol|Rivne|Odessa|Mikolaiv|Lviv|Loutsk|Louhansk|Kiev|Zaporija|Donetsk|Dnipro|Vinitsia|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# |   |   |   |   |   |   |   |   |   |  0 |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
# Une fois rentré chez vous, vous implémentez le graphe permettant d'appliquer le programme créé et aider votre ami en lui disant par quelles villes il devra passer. (vérifier la véracité de l'info donné à Vladimir précédemment).</div>

# %% [markdown]
# Votre ami Marko décide de faire un road trip en Ukraine. Il souhaite cependant perdre le moins de temps possible. Il se procure donc ce document (qui ne concenrne que les plus grandes villes car il possède une TRES grosse voiture):
# ![image.png](attachment:image.png)

# %%
ukraine = {}

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
# Des petits plaisantins ont détourné des panneaux et préparent une embuscade à Mikolaïv. Marko se retrouve malgré lui à Simferopol (en Crimée). Tombera-t-il dans l'embuscade?</div>
