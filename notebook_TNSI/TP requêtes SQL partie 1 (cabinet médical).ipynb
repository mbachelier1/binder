-- %% [markdown]
-- <div style="padding:5px; border-radius:10px;background-color:lightsalmon;">
-- <h1 style="text-align:center;color:black;"> Premiere partie : Cabinet médical</h1>
-- <h3 style="text-align:center;"> Terminale NSI</h3>
-- <h4 style="text-align:center;"> MB  </h4>
-- </div>

-- %% [markdown]
-- <h2 style="color: orange; font-style: 16px italic verdana;"> Exercice n°1 </h2>

-- %% [markdown]
-- <div class="alert alert-warning" style="border-left:5px solid #8a6d3b;">
-- On affiche les différentes tables de la base de données
--     </div>

-- %%
.tables

-- %% [markdown]
-- <div class="alert alert-warning" style="border-left:5px solid #8a6d3b;">
-- puis on explore les tables une par une
--     </div>

-- %%
SELECT * FROM maladie

-- %%
SELECT * FROM medecin

-- %%
SELECT...

-- %%
...

-- %% [markdown]
-- 1. Etudier les tables et faire le schéma relationnel en précisant les clés primaires et secondaires.
-- https://dbdiagram.io/home

-- %% [markdown]
-- *insérer l'image du schéma ici*

-- %% [markdown]
-- 2. Combien la base contient-elle de patients ? (Afficher le nombre pas la liste)

-- %%
SELECT COUNT(...) 
from ...

-- %% [markdown]
-- 3. Afficher la liste des noms des patients.

-- %%
SELECT ... 
FROM ...

-- %% [markdown]
-- 4.  Afficher la liste de la date et le prix des soins supérieur ou égal à 28€.

-- %%
SELECT ... 
FROM ... 
WHERE Prix...

-- %% [markdown]
-- 5. Afficher les noms des médecins n'ayant pas de spécialité.

-- %%
SELECT ... 
FROM ... 
WHERE ...

-- %% [markdown]
-- <h2 style="color: orange; font-style: 16px italic verdana;">Exercice n°2 </h2>

-- %% [markdown]
-- 1. Afficher la liste des noms des patients et la date de soin correspondant.

-- %%
SELECT ... 
FROM personne JOIN ... ON ...=...

-- %% [markdown]
-- 2. Afficher les médecins que Chloé Abjean a rencontré.

-- %%
SELECT nommed 
FROM ... JOIN (... JOIN soin ON soin.med=...)  ON ... 
WHERE nomper=...

-- %% [markdown]
-- 3. Afficher la liste des prix des soins de Marine LE PETIT

-- %%
SELECT ...
FROM ...
WHERE ...

-- %% [markdown]
-- 4. Afficher le total des coûts précédents

-- %%
SELECT SUM(...)
FROM ...
WHERE ...

-- %% [markdown]
-- 5. Afficher la liste des noms et dates de soin des patients du plus âgé au plus jeune.

-- %%
SELECT ...
FROM ...
ORDER BY ..
